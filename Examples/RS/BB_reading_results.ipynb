# %%
# create a loop to work over all data directories
import os
import pandas as pd
import glob
from numpy import log10
import pickle
import numpy as np

from rtergpy.run import defaults
Defaults=defaults()

edirbase=Defaults.edirbase

from matplotlib import pylab as plt
# %matplotlib inline

# %%
#iterate through all the per-station solutions
#for root, dirs, files in os.walk('/home/ljaffe7/Rtergpy/rterg_events/events/2021/2021011100/00',topdown=True):
df_allwfresults=pd.DataFrame()
df_focmech=pd.DataFrame()

for root, dirs, files in os.walk(edirbase,topdown=True):
    for file in files:
        if file.startswith("Results_") and file.endswith(".pkl"): # only iterate on root that have files like Results_*.pkl
            for root1,dirs1,files1 in os.walk(root,topdown=True): # iterate through all dir (called root) to find specific pkl files
                    for file1 in files1: 
                        if file1.startswith("Etacer_") and file1.endswith(".pkl"):
                            perstationfile=os.path.join(root,file1)
                        elif file1.startswith("Results_") and file1.endswith(".pkl"):
                            resultsfile=os.path.join(root,file1)
                    df_result=pd.read_pickle(resultsfile)
                    ebbcorrpertacmean=df_result["ebbcorrpertacmean"][0]
                        
                    df_perstation=pd.read_pickle(perstationfile)
                    df_perstation['ebbcorrpertacmean']=ebbcorrpertacmean
                    df_perstation['eventname']=df_result["eventname"][0]
                    df_perstation['elat']=df_result["elat"][0]
                    df_perstation['elon']=df_result["elon"][0]
                    df_perstation['edepth']=df_result["edepth"][0] 
                    df_perstation['strike']=df_result["focmech"][0][0]
                    df_perstation['dip']=df_result["focmech"][0][1]
                    df_perstation['rake']=df_result["focmech"][0][2]
                    df_perstation['duration']=df_result["tacer"]
                    #df_perstation['dist_meters']=df_perstation["distance"][0][0]
                    #df_perstation['dist_degrees']=df_perstation["distance"][0][1]
    

                    
                    df_perstation['ebbcorrpertaclognorm']=log10(df_perstation['ebbcorrpertac']/ebbcorrpertacmean)
                    
                    
                    df_allwfresults=pd.concat([df_allwfresults,df_perstation],ignore_index=True)
                    df_allwfresults.to_pickle("BBresults.pkl")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/rtergpy/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/anaconda3/envs/rtergpy/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/rtergpy/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tacer'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [5], in <cell line: 6>()
#      25 df_perstation['dip']=df_result["focmech"][0][1]
#      26 df_perstation['rake']=df_result["focmech"][0][2]
# ---> 27 df_perstation['duration']=df_result["tacer"]
#      28 #df_perstation['dist_meters']=df_perstation["distance"][0][0]
#      29 #df_perstation['dist_degrees']=df_perstation["distance"][0][1]
#      33 df_perstation['ebbcorrpertaclognorm']=log10(df_perstation['ebbcorrpertac']/ebbcorrpertacmean)
#
# File ~/anaconda3/envs/rtergpy/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/anaconda3/envs/rtergpy/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'tacer'

# %%
df_allwfresults
dfB=df_allwfresults[df_allwfresults['channel'] == 'BHZ']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/rtergpy/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/anaconda3/envs/rtergpy/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/rtergpy/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'channel'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 df_allwfresults
# ----> 2 dfB=df_allwfresults[df_allwfresults['channel'] == 'BHZ']
#       3 pd.set_option('display.max_columns', None)
#       4 dfB
#
# File ~/anaconda3/envs/rtergpy/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/anaconda3/envs/rtergpy/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'channel'

# %%
df_allwfresults=pd.DataFrame()
df_focmech=pd.DataFrame()



countofresults=[]
countoftacer=[]
for root, dirs, files in os.walk(edirbase,topdown=True):
    for file in files:
        if file.startswith("Results_") and file.endswith(".pkl"): # only iterate on root that have files like Results_*.pkl
            for root1,dirs1,files1 in os.walk(root,topdown=True): # iterate through all dir (called root) to find specific pkl files
                    for file1 in files1: 
                        if file1.startswith("Etacer_") and file1.endswith(".pkl"):
                            perstationfile=os.path.join(root,file1)
                            countoftacer.append(perstationfile)
                        elif file1.startswith("Results_") and file1.endswith(".pkl"):
                            resultsfile=os.path.join(root,file1)
                            countofresults.append(resultsfile)
                        
print(countofresults)   
print(len(countofresults))
print(len(countoftacer))
# Out:
# ['/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021111000/00/pkls/Results_2021111000.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021081200/00/pkls/Results_2021081200.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021030401/00/pkls/Results_2021030401.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021100900/00/pkls/Results_2021100900.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021081401/00/pkls/Results_2021081401.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021081800/00/pkls/Results_2021081800.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021082201/00/pkls/Results_2021082201.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021020300/00/pkls/Results_2021020300.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021081100/00/pkls/Results_2021081100.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021021000/00/pkls/Results_2021021000.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021121400/00/pkls/Results_2021121400.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021062000/00/pkls/Results_2021062000.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021072100/00/pkls/Results_2021072100.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021030402/00/pkls/Results_2021030402.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021122900/00/pkls/Results_2021122900.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021031600/00/pkls/Results_2021031600.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021090800/00/pkls/Results_2021090800.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021072900/00/pkls/Results_2021072900.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021052100/00/pkls/Results_2021052100.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021051400/00/pkls/Results_2021051400.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021092200/00/pkls/Results_2021092200.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021040300/00/pkls/Results_2021040300.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021100200/00/pkls/Results_2021100200.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021081400/00/pkls/Results_2021081400.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021030500/00/pkls/Results_2021030500.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021021300/00/pkls/Results_2021021300.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021012100/00/pkls/Results_2021012100.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021101100/00/pkls/Results_2021101100.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021030400/00.bak/pkls/Results_2021030400.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021030400/00/pkls/Results_2021030400.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021112800/00/pkls/Results_2021112800.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021050100/00/pkls/Results_2021050100.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021072300/00/pkls/Results_2021072300.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021042400/00/pkls/Results_2021042400.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021051200/00/pkls/Results_2021051200.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021051900/00/pkls/Results_2021051900.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021082200/00/pkls/Results_2021082200.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021012300/00/pkls/Results_2021012300.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021032000/00/pkls/Results_2021032000.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021042500/00/pkls/Results_2021042500.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021081600/00/pkls/Results_2021081600.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2021BB/2021011100/00/pkls/Results_2021011100.pkl', '/home/ljaffe7/Rtergpy/rterg_events/events/2020 ...
# 275
# 275
