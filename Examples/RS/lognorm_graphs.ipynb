# %%
import pickle
import pandas as pd
from matplotlib import pylab as plt
# %matplotlib inline
import numpy as np

# %%
notdf = pd.read_pickle('0290results.pkl')
pd.set_option('display.max_columns', None)

df1=notdf[notdf['npts'] ==36001] 
df=df1[df1['eventname']!= '2019?'] #no 2019 events for now
df
# Out:
#            netstatchan network station location channel  \
# 1      AM.R9CDF.00.EHZ      AM   R9CDF       00     EHZ
# 2      AM.RAA90.00.EHZ      AM   RAA90       00     EHZ
# 3      AM.RB079.00.EHZ      AM   RB079       00     EHZ
# 4      AM.RC74C.00.EHZ      AM   RC74C       00     EHZ
# 5      AM.RC98F.00.EHZ      AM   RC98F       00     EHZ
# ...                ...     ...     ...      ...     ...
# 20678  AM.S2D97.00.EHZ      AM   S2D97       00     EHZ
# 20679  AM.S4458.00.EHZ      AM   S4458       00     EHZ
# 20680  AM.S8086.00.EHZ      AM   S8086       00     EHZ
# 20681  AM.S8618.00.EHZ      AM   S8618       00     EHZ
# 20682  AM.SAC78.00.EHZ      AM   SAC78       00     EHZ
#
#                          starttime                      endtime  \
# 1      2022-05-26T15:42:42.301999Z  2022-05-26T15:48:42.301999Z
# 2      2022-05-26T15:42:40.225000Z  2022-05-26T15:48:40.225000Z
# 3      2022-05-26T15:42:36.289000Z  2022-05-26T15:48:36.289000Z
# ...

# %%
df[df["ebbcorrpertaclognorm"]> 10].head()
# Out:
#          netstatchan network station location channel  \
# 139  AM.RCFE6.00.EHZ      AM   RCFE6       00     EHZ
# 245  AM.RA9CF.00.EHZ      AM   RA9CF       00     EHZ
# 301  AM.R0300.00.EHZ      AM   R0300       00     EHZ
# 303  AM.R04C9.00.EHZ      AM   R04C9       00     EHZ
# 323  AM.R286C.00.EHZ      AM   R286C       00     EHZ
#
#                        starttime                      endtime  \
# 139  2022-01-07T17:51:19.286000Z  2022-01-07T17:57:19.286000Z
# 245  2022-05-10T23:12:56.237999Z  2022-05-10T23:18:56.237999Z
# 301  2022-01-11T12:44:43.955000Z  2022-01-11T12:50:43.955000Z
# 303  2022-01-11T12:46:02.590999Z  2022-01-11T12:52:02.590999Z
# 323  2022-01-11T12:46:02.587000Z  2022-01-11T12:52:02.587000Z
#
#                       phasePtime sampling_rate delta   npts calib          az  \
# 139  2022-01-07T17:52:19.288103Z         100.0  0.01  36001   1.0  152.487004
# 245  2022-05-10T23:13:56.241670Z         100.0  0.01  36001   1.0    0.806986
# ...

# %%
#norm vs. depth
plt.figure()
df.plot(x ='edepth', y='ebbcorrpertaclognorm', kind = 'scatter')
plt.title('Ebbcorrpertaclognorm vs. Depth')
plt.ylim([-2,2])
plt.show()

# %%
#norm vs distance
plt.figure()
df.plot(x ='dist_degrees', y='ebbcorrpertaclognorm', kind = 'scatter')
plt.title('Ebbcorrpertaclognorm vs. Distance')
#plt.ylim([-2,2])
plt.show()

# %%
plt.figure()
df.plot(x ='rake', y='ebbcorrpertaclognorm', kind = 'scatter')
plt.title('Ebbcorrpertaclognorm vs. Rake')
plt.ylim([-2,2])
plt.show()

# %%
#norm for strike slip 

df_strikeslip1=df[df['rake'] <-135] 
df_strikeslip2=df[df['rake'] >135]
df3=df[df['rake'] >-45]
df_strikeslip3=df3[df3['rake'] <45]

df_strikeslip1=df_strikeslip1.append([df_strikeslip2,df_strikeslip3])

plt.figure()
df_strikeslip1.plot(x='rake', y='ebbcorrpertaclognorm', kind = 'scatter')
plt.title('Strike-Slip Faulting')
plt.ylim([-2,2])
plt.show()
# Out:
# /tmp/ipykernel_3814/2770960668.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_strikeslip1=df_strikeslip1.append([df_strikeslip2,df_strikeslip3])

# %%
#norm for normal faulting
df1=df[df['rake'] >-135]
df_normal=df1[df1['rake'] <-45]

plt.figure()
df_normal.plot(x='rake', y='ebbcorrpertaclognorm', kind = 'scatter')
plt.title('Normal Faulting')
plt.ylim([-2,2])

plt.show()

# %%
#norm for thrust 
df2=df[df['rake'] >45]
df_thrust=df2[df2['rake'] <135]

plt.figure()
df_thrust.plot(x='rake', y='ebbcorrpertaclognorm', kind = 'scatter')
plt.title('Thrust Faulting')
plt.ylim([-2,2])

plt.show()
