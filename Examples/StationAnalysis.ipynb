# %%
import pickle
import numpy as np
import pandas as pd

# %%
df=pd.read_pickle('NormMeanErgs.pkl')
df
# Out:
#         eventname  RS Median Tacer Energy Station Name  Station Distance  \
# 0      2022052601            1.503072e+15        R9CDF         27.535287
# 1      2022052601            8.911960e+14        RAA90         27.304219
# 2      2022052601            5.852942e+15        RB079         26.866319
# 3      2022052601            1.881909e+16        RC74C         28.636012
# 4      2022052601            5.119612e+14        RC98F         28.273964
# ...           ...                     ...          ...               ...
# 13110  2021011100            3.959968e+15        RFF1D         55.886105
# 13111  2021011100            2.791159e+15        S0306         24.280720
# 13112  2021011100            1.068487e+18        S1108         58.186981
# 13113  2021011100            1.987318e+14        S4458         23.856543
# 13114  2021011100            2.884313e+15        SAC78         74.757223
#
#       Event Azimuth  Event Rake  Event Depth  Average BB Median Tacer Energy  \
# ...

# %%
stationlist=df.drop_duplicates(subset=['Station Name'])
stationlist=stationlist['Station Name']

for station in stationlist:
    
    dfstation=pd.DataFrame
    dfstation=df[df['Station Name']==station]
    posdfstation=dfstation[dfstation['Normalization']>0]
    negdfstation=dfstation[dfstation['Normalization']<0]
    #posmean=np.mean(posdfstation['Normalization'])
    #negmean=np.mean(negdfstation['Normalization'])
    posdfstation['positive']=np.mean(posdfstation['Normalization'])
    negdfstation['negative']=np.mean(negdfstation['Normalization'])
    
    df_pos=pd.DataFrame()
    df_neg=pd.DataFrame()
    
    df_pos=pd.concat([df_pos,posdfstation],ignore_index=True)
    df_pos.to_pickle("RSstationsP.pkl")
    
    df_neg=pd.concat([df_neg,negdfstation],ignore_index=True)
    df_neg.to_pickle("RSstationsN.pkl")
# Out:
# /tmp/ipykernel_7338/632664265.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   posdfstation['positive']=np.mean(posdfstation['Normalization'])
# /tmp/ipykernel_7338/632664265.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negdfstation['negative']=np.mean(negdfstation['Normalization'])
# /tmp/ipykernel_7338/632664265.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
test=pd.read_pickle('RSstationsP.pkl')
test
# Out:
# Empty DataFrame
# Columns: [eventname, RS Median Tacer Energy, Station Name, Station Distance, Event Azimuth, Event Rake, Event Depth, Average BB Median Tacer Energy, Normalization, positive]
# Index: []
