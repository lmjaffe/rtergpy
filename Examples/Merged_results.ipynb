# %%
import pandas as pd
import pickle

# %%
dfRS=pd.read_pickle('Combined_Results_RS.pkl')
dfBB=pd.read_pickle('Combined_Results_BB.pkl')

# %%
dfBB
# Out:
#       eventname iteration                        etime   elat    elon edepth  \
# 0    2019010500        00  2019-01-05T19:25:38.500000Z   -8.1  -71.68  588.1
# 1    2019010600        00  2019-01-06T17:27:19.000000Z   2.48  126.63   34.9
# 2    2019011500        00  2019-01-15T18:06:34.300000Z -13.41   166.5   39.0
# 3    2019012000        00  2019-01-20T01:32:52.500000Z -30.18  -71.39   60.7
# 4    2019012200        00  2019-01-22T19:01:43.600000Z -43.01   42.17   18.5
# ..          ...       ...                          ...    ...     ...    ...
# 115  2022051900        00  2022-05-19T10:13:31.700000Z -54.02   158.7   23.5
# 116  2022052600        00  2022-05-26T12:02:20.300000Z -14.75  -70.28  237.8
# 117  2022052601        00  2022-05-26T15:37:58.200000Z -22.81  172.14   29.1
# 118  2022060400        00  2022-06-04T13:17:48.500000Z  -57.8   148.2   12.0
# 119  2022071200        00  2022-07-12T19:17:00.400000Z  -22.5  -114.0   12.0
#
# ...

# %%
dfRS
# Out:
#      eventname iteration                        etime   elat    elon edepth  \
# 0   2019010600        00  2019-01-06T17:27:19.000000Z   2.48  126.63   34.9
# 1   2019011500        00  2019-01-15T18:06:34.300000Z -13.41   166.5   39.0
# 2   2019012000        00  2019-01-20T01:32:52.500000Z -30.18  -71.39   60.7
# 3   2019012200        00  2019-01-22T19:01:43.600000Z -43.01   42.17   18.5
# 4   2019040900        00  2019-04-09T17:53:58.400000Z -58.71   -24.6   42.6
# ..         ...       ...                          ...    ...     ...    ...
# 77  2022033100        00  2022-03-31T05:44:01.800000Z -22.49  170.46   23.0
# 78  2022051900        00  2022-05-19T10:13:31.700000Z -54.02   158.7   23.5
# 79  2022052601        00  2022-05-26T15:37:58.200000Z -22.81  172.14   29.1
# 80  2022060400        00  2022-06-04T13:17:48.500000Z  -57.8   148.2   12.0
# 81  2022071200        00  2022-07-12T19:17:00.400000Z  -22.5  -114.0   12.0
#
# ...

# %%
df_comparisons=pd.DataFrame()

# %%
df_comparisons=pd.DataFrame()
df_comparisons1=pd.DataFrame()

df_comparisons['eventname']=dfRS["eventname"]
df_comparisons['RS ebbcorrpertacmean']=dfRS["ebbcorrpertacmean"]
df_comparisons1['eventname2']=dfBB["eventname"]
df_comparisons1['BB ebbcorrpertacmean']=dfBB["ebbcorrpertacmean"]

pd.set_option('display.max_rows', None)
df_comparisons=pd.concat([df_comparisons, df_comparisons1], axis=1)

# %%
df_comparisons
# Out:
#       eventname   RS ebbcorrpertacmean  eventname2    BB ebbcorrpertacmean
# 0    2019010600   1108474049265160.125  2019010500     450032685779565.875
# 1    2019011500   1088241749123727.125  2019010600     158971359863921.625
# 2    2019012000     1174846909253225.0  2019011500    210826541054292.6875
# 3    2019012200    762881190798511.375  2019012000    366728401528027.3125
# 4    2019040900     1836894943959647.0  2019012200    357705799180193.3125
# 5    2019041200    19549086852325436.0  2019020100   163376761078372.09375
# 6    2019050600     6504798735925477.0  2019022200      5821994132481977.0
# 7    2019051400    35855121693368576.0  2019030100      1743324799259105.5
# 8    2019052600    91554496999599744.0  2019040900    190397615943516.1875
# 9    2019061500     3320375082728238.0  2019041200       883083889001017.5
# 10   2019070700     6363310248068288.0  2019050600     1991299802537882.75
# ...
